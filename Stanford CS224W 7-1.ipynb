# %% [markdown]
# # A general Perspective on GNNs

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 무슨 애기인지 잘몰라도 된다.
# ### - 첫번째 레이어
#   - Aggregation
#   - Message
# - 이 두가지 개념을 어떻게 잡을 것인지가 중요하다.
#
# ### - 두번째 레이어
#   - 첫번째 레이어와 두번재 레이어를 어떻게 연결할지가 중요하다.
#
# ### - 세번째
#   - Raw input graph != computational graph
#   - Graph feature augmentation
#   - Graph structure manipulation
#
# ### - 마지막
#   - 어떤 종류의 학습, 어떤 종류의 목적함수, 어떤 종류의 작업을 할 건지가 중요하다.
